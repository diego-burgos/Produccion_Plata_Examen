# %% [markdown]
# <a href="https://colab.research.google.com/github/diego-burgos/Produccion_Plata_Examen/blob/main/data_plata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Importamos la data de las siguientes paginas:
#
# Perú: https://estadisticas.bcrp.gob.pe/estadisticas/series/mensuales/resultados/RD12996DM/html/2020-1/2022-12/
#
# Mexico: https://www.sgm.gob.mx/SINEMGobMx/produccion_minera.jsp
#
# recolectamos la data mensual de la produccion de plata de los años 2020 - 2022

# %%
datos = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vS_SJU9SHkg6GZu2HjCOuRdxYZJGXSzxIwXKzX2l3aSmZTvKiq7XNMHKhf3AFeCVw/pub?output=csv", index_col="Fecha")

# %% [markdown]
# Mostramos los datos

# %%
datos
# Out:
#               Peru   Mexico
# Fecha
# 1/1/2020   323.781  326.215
# 1/2/2020   318.253  307.516
# 1/3/2020   215.291  347.102
# 1/4/2020    84.973  203.234
# 1/5/2020   116.152  251.399
# 1/6/2020   264.965  327.389
# 1/7/2020   226.912  367.002
# 1/8/2020   265.290  389.930
# 1/9/2020   292.208  288.609
# 1/10/2020  289.040  309.212
# 1/11/2020  294.496  325.364
# 1/12/2020  317.682  366.172
# 1/1/2021   275.910  330.001
# 1/2/2021   260.125  344.260
# 1/3/2021   265.917  363.431
# 1/4/2021   256.891  358.910
# 1/5/2021   283.148  355.440
# 1/6/2021   282.824  364.166
# 1/7/2021   282.440  364.295
# 1/8/2021   296.499  342.267
# 1/9/2021   276.645  358.450
# 1/10/2021  269.436  322.521
# 1/11/2021  271.828  331.052
# 1/12/2021  295.230  341.162
# 1/1/2022   254.326  347.204
# 1/2/2022   242.849  348.008
# 1/3/2022   241.446  353.723
# 1/4/2022   247.227  351.753
# 1/5/2022   251.878  355.130
# 1/6/2022   257.645  368.954
# 1/7/2022   252.058  348.008
# 1/8/2022   270.286  355.582
# ...

# %% [markdown]
# instalamos la libreria bar-chart-race para generar el grafico de carrera el formato video

# %%
pip install bar-chart-race

# %% [markdown]
# importamos la libreria y generamos el video con la data que queremos mostrar

# %%
import pandas as pd
import bar_chart_race as bcr
bcr.bar_chart_race(df=datos,filename="video_grafico.mp4", title="Producción de Plata entre los paises de Perú y México 2020-2022")
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))

# %%
# prompt: suma tolas las final de la columna mexico

suma_peru = datos['Peru'].sum()
print(f"Suma de la columna 'Peru': {suma_peru}")
# Out:
# Suma de la columna 'Peru': 323780,67318253,14215291,0184972,62116151,73264964,52226911,87265290,35292208,35289039,59294495,64317681,64275910,43260125,40265916,96256891,17283147,89282824,48282440,05296499,39276645,11269436,16271828,08295230,28254325,68242848,52241446,12247226,51251878,23257645,02252057,59270285,83254721,60263906,42244462,16278608,26

# %%
# prompt: suma tolas las final de la columna mexico

suma_mexico = datos['Mexico'].sum()
print(f"Suma de la columna 'Peru': {suma_mexico}")
# Out:
# Suma de la columna 'Peru': 326215,00307516,00347102,00203234,00251399,00327389,00367002,00389930,00288609,00309212,00325364,00366172,00330001,00344260,00363431,00358910,00355440,00364166,00364295,00342267,00358450,00322521,00331052,00341162,00347204,00348008,00353723,00351753,00355130,00368954,00348008,00355582,00348976,00341954,00334327,00329245,00
